# %%
import mlflow
import dagshub
import pandas as pd
from dotenv import load_dotenv
import os

load_dotenv()

tracking_url = os.getenv('mlflow_track_dagshub_url')
repo_owner =os.getenv('repo_owner')
repo_name= os.getenv('repo_name')

# %%
mlflow.set_tracking_uri(tracking_url)
dagshub.init(repo_owner=repo_owner, repo_name= repo_name, mlflow=True)
# Out:
# Initialized MLflow to track repo "godhatpranjal/customer-satisfaction-analysis"
# Repository godhatpranjal/customer-satisfaction-analysis initialized!

# %%
import time

with mlflow.start_run():
    pass
# Out:
# 🏃 View run rogue-steed-923 at: https://dagshub.com/godhatpranjal/customer-satisfaction-analysis.mlflowz/#/experiments/0/runs/e05cb5374cd542f1a687844f20c9ec27
# 🧪 View experiment at: https://dagshub.com/godhatpranjal/customer-satisfaction-analysis.mlflowz/#/experiments/0
